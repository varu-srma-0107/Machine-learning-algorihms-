# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
df =  pd.read_csv(r"C:\Users\LENOVO\Downloads\4. Data Sets\homeprice.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.scatter(df.area,df.price,color="red",marker="+")
plt.xlabel("AREA(sq.ft)")
plt.ylabel("PRICE(US$)")
# Out:
# Text(0, 0.5, 'PRICE(US$)')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']] ,  df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
d=pd.read_csv(r"C:\Users\LENOVO\Downloads\4. Data Sets\homepriceinput.csv")

# %%
d
# Out:
#     Area
# 0   1500
# 1   2300
# 2   2400
# 3   4500
# 4   2500
# 5   1900

# %%
p=reg.predict(d)

# %%
d['prices']=p

# %%
d.to_csv("predicion.csv")

# %%
# %matplotlib inline
plt.scatter(df.area,df.price,color="red",marker="+")
plt.xlabel("AREA(sq.ft)")
plt.ylabel("PRICE(US$)")
plt.plot(df.area,reg.predict(df[["area"]]),color='green')

# %% [markdown]
# SAVE MODEL

# %%
import pickle

# %%
with open ("model_pickle",'wb') as f1:
    pickle.dump(reg,f1)

# %%
with open('model_pickle','rb') as f1:
    np=pickle.load(f1)

# %%
np.predict([[3300]])
# Out:
# array([628715.75342466])
