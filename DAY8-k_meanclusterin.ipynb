# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Desktop\VS Code\ML Projects\Code_basics-ML-Tutorial\k_mean.csv')

# %%
df.head()
# Out:
#       name  age  income
# 0      Rob   27   70000
# 1  Michael   29   90000
# 2    Mohan   29   61000
# 3   Ismail   28   60000
# 4     Kory   42  150000

# %%
plt.scatter(df['age'],df['income'])
plt.xlabel('age')
plt.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %%
km = KMeans(n_clusters=3)

# %%
km
# Out:
# KMeans(n_clusters=3)

# %%
y_predict =km.fit_predict(df[['age','income']])

# %%
df['cluster']= y_predict

# %%
df.head()
# Out:
#       name  age  income  cluster
# 0      Rob   27   70000        1
# 1  Michael   29   90000        1
# 2    Mohan   29   61000        2
# 3   Ismail   28   60000        2
# 4     Kory   42  150000        0

# %%
df0= df[df.cluster==0]
df1= df[df.cluster==1]
df2= df[df.cluster==2]

plt.scatter(df0.age,df0["income"],color='red')
plt.scatter(df1.age,df1["income"],color='blue')
plt.scatter(df2.age,df2["income"],color='green')
plt.xlabel('age')
plt.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %%
scalar = MinMaxScaler()
scalar.fit(df[["income"]])
df['income']= scalar.transform(df[['income']])


scale=MinMaxScaler().fit(df[['age']])
df['age']=scale.transform(df[['age']])
'''features = df.age
scalar.fit(features.values)
features = scalar.transform(features.values)

df,age = pd.DataFrame(features, columns = col_names)'''
df
# Out:
#         name       age    income  cluster
# 0        Rob  0.058824  0.213675        1
# 1    Michael  0.176471  0.384615        1
# 2      Mohan  0.176471  0.136752        2
# 3     Ismail  0.117647  0.128205        2
# 4       Kory  0.941176  0.897436        0
# 5     Gautam  0.764706  0.940171        0
# 6      David  0.882353  0.982906        0
# 7     Andrea  0.705882  1.000000        0
# 8       Brad  0.588235  0.948718        0
# 9   Angelina  0.529412  0.726496        0
# 10    Donald  0.647059  0.786325        0
# 11       Tom  0.000000  0.000000        2
# 12    Arnold  0.058824  0.025641        2
# 13     Jared  0.117647  0.051282        2
# 14     Stark  0.176471  0.038462        2
# 15    Ranbir  0.352941  0.068376        2
# 16    Dipika  0.823529  0.170940        2
# 17  Priyanka  0.882353  0.153846        2
# 18      Nick  1.000000  0.162393        2
# 19      Alia  0.764706  0.299145        1
# 20       Sid  0.882353  0.316239        1
# ...

# %%
km = KMeans(n_clusters=3)
y_predict =km.fit_predict(df[['age','income']])
df['cluster']= y_predict

# %%
df0= df[df.cluster==0]
df1= df[df.cluster==1]
df2= df[df.cluster==2]

plt.scatter(df0.age,df0["income"],color='red')
plt.scatter(df1.age,df1["income"],color='blue')
plt.scatter(df2.age,df2["income"],color='green')
plt.xlabel('age')
plt.ylabel('income')
plt.legend()
# Out:
# No handles with labels found to put in legend.
